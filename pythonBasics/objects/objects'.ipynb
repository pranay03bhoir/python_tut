# %%
class Account:
    def __init__(self, account_number, account_type, initial_balance):
        self.account_number = account_number
        self.account_type = account_type
        self.balance = initial_balance

    def deposit(self, amount):
        # should also check that amount is a numerical value!
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount}")
            print(f"New balance is: {self.balance}")
        else:
            print(f"{amount} is an invalid amount.")

    def withdraw(self, amount):
        # should also check that amount is a numerical value!
        if amount > 0 and amount <= self.balance:
            self.balance -= amount
            print(f"Withdrawal: {amount}")
            print(f"New Balance: {self.balance}")
        else:
            if amount < 0:
                print(f"{amount} is an invalid amount.")
            else:
                print("Insufficient funds.")
                print(f"Current balance is {self.balance}")

# %%
my_account = Account('123-456','savings',1_000.00)

# %%
my_account.account_number
# Out:
# '123-456'

# %%
my_account.account_type
# Out:
# 'savings'

# %%
my_account.balance
# Out:
# 1000.0

# %%
my_account.deposit(1200)
# Out:
# Deposited 1200
# New balance is: 2200.0

# %%
my_account.withdraw(780)
# Out:
# Withdrawal: 780
# New Balance: 1420.0

# %%
my_account.withdraw(20_000)
# Out:
# Insufficient funds.
# Current balance is 1420.0

# %%
# This is one of the dunder methods in python
(10).__add__(25)
# Out:
# 35

# %%
0.125.as_integer_ratio()
# Out:
# (1, 8)

# %%
0.1.as_integer_ratio()
# Out:
# (3602879701896397, 36028797018963968)
